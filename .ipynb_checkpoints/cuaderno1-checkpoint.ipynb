# %%
import pandas as pd

# %%
# !pip install faker
# Out:
# Collecting faker
#   Using cached faker-37.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from faker) (2025.2)
# Using cached faker-37.1.0-py3-none-any.whl (1.9 MB)
# Installing collected packages: faker
# Successfully installed faker-37.1.0

# %%
from faker import Faker
# Crear instancia de Faker
fake = Faker()

# %%
lista=[]

# %%
for i in range(0,10000):
    lista.append({
        'nombre': fake.name(),
        'apellido': fake.last_name(),
        'email': fake.email(),
        'direccion': fake.address()
    })

# %%
lista
# Out:
# [{'nombre': 'Laura Bryan',
#   'apellido': 'Hunter',
#   'email': 'xbarnett@example.net',
#   'direccion': '1338 Amy Valley Apt. 265\nTammyfurt, SD 98889'},
#  {'nombre': 'Katherine Smith',
#   'apellido': 'Anderson',
#   'email': 'terrihernandez@example.net',
#   'direccion': 'Unit 3379 Box 0005\nDPO AP 28086'},
#  {'nombre': 'Bernard Gardner',
#   'apellido': 'Thomas',
#   'email': 'mayojill@example.org',
#   'direccion': '539 Lawrence Stream\nEast Christophertown, CA 74573'},
#  {'nombre': 'Sandy Harris',
#   'apellido': 'Mckinney',
#   'email': 'kevin87@example.org',
#   'direccion': 'USNS Brown\nFPO AA 25533'},
#  {'nombre': 'Shannon Pope',
#   'apellido': 'Martin',
#   'email': 'wendywells@example.net',
#   'direccion': '5881 Johnson Track\nGayton, WV 96401'},
#  {'nombre': 'Mark Clark',
#   'apellido': 'Hernandez',
#   'email': 'jamie82@example.net',
#   'direccion': '00957 Erika Lake Suite 595\nPort Nicole, OH 44622'},
#  {'nombre': 'Brian Pierce',
#   'apellido': 'Johns',
#   'email': 'ricky01@example.com',
#   'direccion': '9066 Turner Stravenue Suite 724\nFuentesberg, WA 31223'},
#  {'nombre': 'Michael Greene',
#   'apellido': 'Robinson',
#   'email': 'yharvey@example.net',
#   'direccion': '929 Allison Meadows\nSouth Shawn, WY 22235'},
#  {'nombre': 'Edward Campbell',
#   'apellido': 'Oneill',
#   'email': 'pscott@example.net',
#   'direccion': '6979 Kim Drive\nJessicaburgh, CO 13947'},
#  {'nombre': 'Patricia Casey',
#   'apellido': 'Hernandez',
#   'email': 'xvilla@example.com',
#   'direccion': '4919 Myers Islands Apt. 197\nWalkerbury, AZ 03790'},
#  {'nombre': 'Timothy Gross',
#   'apellido': 'Waters',
#   'email': 'lisasmith@example.com',
#   'direccion': '45029 Melissa Flats Apt. 018\nAndrewsside, VA 60002'},
#  {'nombre': 'Mary Stuart',
#   'apellido': 'Molina',
#   'email': 'afoley@example.com',
#   'direccion': '788 Brenda Track Apt. 649\nSouth Robin, OH 14696'},
#  {'nombre': 'Paul Doyle',
#   'apellido': 'Weber',
#   'email': 'parkergraves@example.com',
#   'direccion': '2824 Stewart Hills Apt. 015\nSouth Paulaside, TX 02547'},
#  {'nombre': 'Richard Pruitt',
#   'apellido': 'Long',
#   'email': 'collin90@example.com',
#   'direccion': '00829 Whitney Run Apt. 231\nTuckerbury, CO 32324'},
#  {'nombre': 'Michael Summers',
#   'apellido': 'Thomas',
#   'email': 'ftaylor@example.net',
#   'direccion': '1105 Taylor Square\nWyattstad, KY 90056'},
#  {'nombre': 'Jason Jarvis',
#   'apellido': 'Thompson',
#   'email': 'bryan97@example.com',
#   'direccion': '01048 Stewart Grove\nElijahbury, NE 31640'},
#  {'nombre': 'Chad Jenkins',
#   'apellido': 'Morgan',
#   'email': 'johnsonmatthew@example.org',
#   'direccion': '9447 Bradley Spur\nKleinburgh, SC 46343'},
#  {'nombre': 'Gina Villanueva',
#   'apellido': 'Beltran',
#   'email': 'xchambers@example.org',
#   'direccion': '694 Nancy Point\nNew Patricia, ID 53327'},
#  {'nombre': 'Matthew Shah',
#   'apellido': 'Mueller',
#   'email': 'taylortamara@example.net',
#   'direccion': '0238 Miller Gardens Apt. 359\nWest Ashleyburgh, NJ 09733'},
#  {'nombre': 'Ryan Franklin',
#   'apellido': 'Galvan',
#   'email': 'haleyscott@example.com',
#   'direccion': '42312 Knapp Coves Suite 441\nWest Rodneyborough, WV 71275'},
#  {'nombre': 'John Evans',
#   'apellido': 'Cohen',
#   'email': 'amartin@example.com',
#   'direccion': '47620 Theresa Ways Apt. 381\nNew Cassandraport, MH 91434'},
#  {'nombre': 'Hannah Lewis',
#   'apellido': 'Jones',
#   'email': 'ckelley@example.org',
#   'direccion': 'Unit 6093 Box 7761\nDPO AE 65535'},
#  {'nombre': 'Jeffrey Francis',
#   'apellido': 'Rivas',
#   'email': 'elizabethwarren@example.net',
#   'direccion': '90873 Boyd Highway\nSouth Rebekah, VI 98926'},
#  {'nombre': 'Jade Mcdaniel',
#   'apellido': 'Perry',
#   'email': 'walterjasmine@example.org',
#   'direccion': 'Unit 4309 Box 5556\nDPO AE 95633'},
#  {'nombre': 'Sarah Parsons',
#   'apellido': 'Anderson',
#   'email': 'michael76@example.com',
#   'direccion': '50796 Doyle Locks Apt. 019\nLake Jessica, KS 72714'},
#  {'nombre': 'Erik Rivers',
#   'apellido': 'Wilkins',
#   'email': 'megancunningham@example.com',
#   'direccion': '9170 Cooper Lock\nJessicaburgh, NY 75317'},
#  {'nombre': 'Richard Sweeney',
#   'apellido': 'Ortiz',
#   'email': 'kimberly13@example.org',
#   'direccion': '411 Jeffrey Glen Apt. 758\nWest Terri, MH 67070'},
#  {'nombre': 'Holly Newman',
#   'apellido': 'Watson',
#   'email': 'brandon86@example.org',
#   'direccion': '500 Lacey Landing\nEast Kevin, MO 63699'},
#  {'nombre': 'Elizabeth Stokes',
#   'apellido': 'Li',
#   'email': 'miguel87@example.org',
#   'direccion': '81975 Joshua Forge Apt. 438\nNew Sarah, MP 67384'},
#  {'nombre': 'Michelle Palmer MD',
#   'apellido': 'Conway',
#   'email': 'nhicks@example.org',
#   'direccion': 'Unit 4736 Box 1056\nDPO AA 36666'},
#  {'nombre': 'Mr. Warren Pearson',
#   'apellido': 'Reed',
#   'email': 'bradyrodriguez@example.org',
#   'direccion': '23900 Barrett Isle\nPort Laurenville, LA 68332'},
#  {'nombre': 'Gary Vargas',
#   'apellido': 'Baker',
#   'email': 'christiecastillo@example.org',
#   'direccion': '7709 Hicks Locks Apt. 369\nPort Raymondmouth, NV 93923'},
#  {'nombre': 'Vanessa Shepard',
#   'apellido': 'Campbell',
#   'email': 'christopherburgess@example.com',
#   'direccion': '2631 Olson Canyon Apt. 380\nNorth Carol, PA 20498'},
#  {'nombre': 'Shirley Simpson',
#   'apellido': 'Christensen',
#   'email': 'ronald47@example.com',
#   'direccion': '637 Herrera Rapid Apt. 097\nOrrfurt, AK 78500'},
#  {'nombre': 'Lisa Sutton',
#   'apellido': 'Avery',
#   'email': 'paulburns@example.net',
#   'direccion': '883 Wilson Turnpike Apt. 362\nMarkhaven, NC 15296'},
#  {'nombre': 'Mary Moore',
#   'apellido': 'Berg',
#   'email': 'ramirezantonio@example.com',
#   'direccion': '330 Haley Forge\nEast Jerryberg, SC 35793'},
#  {'nombre': 'Kelly Payne',
#   'apellido': 'Hall',
#   'email': 'randall95@example.org',
#   'direccion': '03260 Catherine Greens Apt. 365\nNathanielchester, UT 74827'},
#  {'nombre': 'Zachary Garcia',
#   'apellido': 'Reed',
#   'email': 'greerjoseph@example.net',
#   'direccion': '901 Erin Fall Apt. 205\nSouth Eric, VI 18106'},
#  {'nombre': 'Michael Wright',
#   'apellido': 'Collins',
#   'email': 'mariaoconnor@example.net',
#   'direccion': '407 Bradley Port Apt. 884\nHernandezview, NJ 46082'},
#  {'nombre': 'Rachael Kemp',
#   'apellido': 'Brown',
#   'email': 'inorris@example.net',
#   'direccion': '24254 Gates Fork Suite 407\nRonnieberg, AL 02610'},
#  {'nombre': 'Jasmine Simpson',
#   'apellido': 'Sanchez',
#   'email': 'sararodriguez@example.org',
#   'direccion': '4168 Lisa Row Apt. 046\nEast James, WY 39299'},
#  {'nombre': 'Kim Gutierrez',
#   'apellido': 'Rivera',
#   'email': 'icallahan@example.com',
#   'direccion': '417 Velez Trail\nJenniferberg, SD 04403'},
#  {'nombre': 'Sheila York',
#   'apellido': 'Martinez',
#   'email': 'ramosheather@example.net',
#   'direccion': '9702 Gillespie Rest Suite 213\nWest Davidfurt, SD 16903'},
#  {'nombre': 'Amanda Harvey',
#   'apellido': 'Johnson',
#   'email': 'wwallace@example.com',
#   'direccion': '59298 Ramsey Branch\nSamuelberg, MO 88204'},
#  {'nombre': 'Nathaniel Gates',
#   'apellido': 'Anderson',
#   'email': 'pmurphy@example.net',
#   'direccion': '106 Joshua Trace Suite 450\nNorth Laura, PR 21781'},
#  {'nombre': 'Steven Armstrong',
#   'apellido': 'Davis',
#   'email': 'ethompson@example.net',
#   'direccion': '44774 Griffin Union Suite 372\nAmandatown, NV 51834'},
#  {'nombre': 'Corey Estrada',
#   'apellido': 'Meza',
#   'email': 'uwood@example.org',
#   'direccion': '32628 Schultz Dale\nPort Christopherview, MN 27311'},
#  {'nombre': 'Kayla Ramirez',
#   'apellido': 'Davidson',
#   'email': 'richardsonjoseph@example.net',
#   'direccion': '5592 Tiffany Isle Apt. 855\nGonzalezborough, MS 91136'},
#  {'nombre': 'Crystal Nichols',
#   'apellido': 'Smith',
#   'email': 'heather10@example.org',
#   'direccion': '2278 Gerald Bridge\nEast Meredith, VI 46972'},
#  {'nombre': 'Jared Sullivan',
#   'apellido': 'Miller',
#   'email': 'jenniferclark@example.com',
#   'direccion': '1670 William Circle\nLake Eric, RI 80437'},
#  {'nombre': 'Arthur Smith',
#   'apellido': 'Ramirez',
#   'email': 'browndennis@example.net',
#   'direccion': '22121 Hull Mews\nAdamsborough, DC 36036'},
#  {'nombre': 'Antonio Hendricks',
#   'apellido': 'Hughes',
#   'email': 'michaelsnow@example.net',
#   'direccion': '30937 Michael Forest\nMccormickfort, NV 49320'},
#  {'nombre': 'Christopher Dudley',
#   'apellido': 'Ramos',
#   'email': 'alexis11@example.org',
#   'direccion': '00563 Baker Keys\nRyanburgh, AS 75998'},
#  {'nombre': 'Adam Riggs',
#   'apellido': 'Ward',
#   'email': 'eglover@example.org',
#   'direccion': '395 Amy Springs Suite 517\nLake Randallchester, ND 93773'},
#  {'nombre': 'Leslie Barnes',
#   'apellido': 'Johnson',
#   'email': 'william93@example.com',
#   'direccion': '222 Ball Place\nLake Colleenmouth, GA 65342'},
#  {'nombre': 'John Davis',
#   'apellido': 'Riley',
#   'email': 'stephen71@example.com',
#   'direccion': 'PSC 2221, Box 1290\nAPO AA 67029'},
#  {'nombre': 'Robert Thomas',
#   'apellido': 'Thompson',
#   'email': 'jasonevans@example.com',
#   'direccion': '534 Davis Village Apt. 488\nNew Diana, MO 72368'},
#  {'nombre': 'Ashley Smith',
#   'apellido': 'Williams',
#   'email': 'elizabeth18@example.net',
#   'direccion': '3344 Weber Meadows Suite 523\nLake Michele, LA 24810'},
#  {'nombre': 'Abigail Kaiser',
#   'apellido': 'Kennedy',
#   'email': 'jacksoncynthia@example.com',
#   'direccion': '59035 Norris Ford\nMichaelchester, DC 94463'},
#  {'nombre': 'Alex Reyes',
#   'apellido': 'Salazar',
#   'email': 'jonescarol@example.com',
#   'direccion': '5686 Stephanie Stravenue Apt. 434\nSouth Tyrone, AR 66640'},
#  {'nombre': 'Crystal Cooke',
#   'apellido': 'Powers',
#   'email': 'paul25@example.net',
#   'direccion': '0534 Neal Falls Suite 117\nBennettport, IN 71462'},
#  {'nombre': 'Michelle Levy',
#   'apellido': 'Pruitt',
#   'email': 'cortezdavid@example.com',
#   'direccion': '077 Faith Plains\nKrystalbury, HI 19668'},
#  {'nombre': 'Jessica Hernandez',
#   'apellido': 'Peterson',
#   'email': 'andrea60@example.org',
#   'direccion': '718 Rachel Pass\nWest Gary, ND 24690'},
#  {'nombre': 'Ryan Gordon',
#   'apellido': 'Rios',
#   'email': 'sancheznichole@example.org',
#   'direccion': '2590 Phillips Inlet Apt. 277\nElizabethstad, NC 65322'},
#  {'nombre': 'Sally Douglas',
#   'apellido': 'Hensley',
#   'email': 'lloydevan@example.net',
#   'direccion': '23416 Fitzpatrick Mills\nAdamview, AR 10220'},
#  {'nombre': 'Michael Martin',
#   'apellido': 'Thomas',
#   'email': 'stephensonanna@example.org',
#   'direccion': '30124 Barry Ports\nEast Victorbury, WV 49805'},
#  {'nombre': 'Scott Thompson',
#   'apellido': 'Brown',
#   'email': 'normanjames@example.org',
#   'direccion': '951 Sarah Wells\nHallberg, HI 44366'},
#  {'nombre': 'Karen Ball',
#   'apellido': 'Webb',
#   'email': 'anne74@example.net',
#   'direccion': '44310 Butler Place\nNorth Nicoletown, GU 17397'},
#  {'nombre': 'Janet Pearson',
#   'apellido': 'Boyd',
#   'email': 'josephevans@example.net',
#   'direccion': 'PSC 2785, Box 1107\nAPO AA 92948'},
#  {'nombre': 'Tara Middleton',
#   'apellido': 'Coleman',
#   'email': 'ckramer@example.net',
#   'direccion': '136 Sandoval Inlet Suite 664\nMarcustown, KS 96063'},
#  {'nombre': 'Haley Rowe',
#   'apellido': 'Ayala',
#   'email': 'coreymurphy@example.net',
#   'direccion': '79569 Anderson Ridge Suite 937\nKaylaside, MP 88340'},
#  {'nombre': 'Amanda Lynch',
#   'apellido': 'Hall',
#   'email': 'christygraves@example.org',
#   'direccion': '98207 Castro Glen\nLake Kimberly, GA 90317'},
#  {'nombre': 'Amanda Tucker',
#   'apellido': 'Flores',
#   'email': 'uhanson@example.net',
#   'direccion': '68048 Thomas Lane Suite 614\nEmilystad, PR 64787'},
#  {'nombre': 'Joshua Mack',
#   'apellido': 'Howard',
#   'email': 'morganjanet@example.org',
#   'direccion': 'Unit 3026 Box 8309\nDPO AE 31109'},
#  {'nombre': 'Brittany Jones',
#   'apellido': 'Lawson',
#   'email': 'roblesdavid@example.org',
#   'direccion': 'PSC 3061, Box 9000\nAPO AA 10233'},
#  {'nombre': 'Raymond Wells',
#   'apellido': 'Payne',
#   'email': 'jonesveronica@example.com',
#   'direccion': '39378 Emily Plains Suite 935\nNicolemouth, MA 68030'},
#  {'nombre': 'Gary Barron',
#   'apellido': 'Dunn',
#   'email': 'loriferguson@example.org',
#   'direccion': '249 Victoria Inlet\nPowellview, AR 32713'},
#  {'nombre': 'David Jordan',
#   'apellido': 'Freeman',
#   'email': 'waltonrandall@example.org',
#   'direccion': 'PSC 6201, Box 0003\nAPO AA 94577'},
#  {'nombre': 'Natalie Gilbert',
#   'apellido': 'Cummings',
#   'email': 'edward03@example.com',
#   'direccion': '22823 Ayers Lodge Apt. 133\nEast John, MH 62325'},
#  {'nombre': 'Jeffrey Sparks',
#   'apellido': 'Grant',
#   'email': 'briancox@example.net',
#   'direccion': '86653 Desiree Falls\nNew Alexandria, NY 54998'},
#  {'nombre': 'Kathleen Terry',
#   'apellido': 'Rivers',
#   'email': 'millerbonnie@example.org',
#   'direccion': '30973 Silva Motorway\nEast Ginachester, AZ 58493'},
#  {'nombre': 'Rebecca Lopez',
#   'apellido': 'Norris',
#   'email': 'joneskaitlyn@example.org',
#   'direccion': '7134 Randy Trail Apt. 289\nWest Valerie, OR 02723'},
#  {'nombre': 'Patricia Wright',
#   'apellido': 'Mann',
#   'email': 'alex54@example.com',
#   'direccion': 'PSC 1172, Box 7020\nAPO AP 66759'},
#  {'nombre': 'Amanda Casey',
#   'apellido': 'Stokes',
#   'email': 'daniel04@example.com',
#   'direccion': '71882 Glenn Canyon Apt. 493\nChasemouth, FL 37808'},
#  {'nombre': 'Scott Casey',
#   'apellido': 'Long',
#   'email': 'dlindsey@example.com',
#   'direccion': '385 Curtis Motorway Suite 974\nRandallfurt, WA 80440'},
#  {'nombre': 'Andrea Harrell',
#   'apellido': 'Vargas',
#   'email': 'cody48@example.org',
#   'direccion': '01824 Andre Station Suite 239\nSouth Brenda, AZ 39326'},
#  {'nombre': 'James Washington',
#   'apellido': 'Wilson',
#   'email': 'veronica59@example.org',
#   'direccion': '958 Williams Streets Apt. 402\nNew Lisa, CT 66628'},
#  {'nombre': 'Richard Sanchez',
#   'apellido': 'Guerrero',
#   'email': 'smithselena@example.org',
#   'direccion': '140 Jordan Trail Apt. 799\nNew Sherryville, ND 28114'},
#  {'nombre': 'Brittany Hill',
#   'apellido': 'Graves',
#   'email': 'zachary10@example.com',
#   'direccion': '436 Elizabeth Circles Suite 975\nMarkmouth, VA 61460'},
#  {'nombre': 'Kenneth Larsen',
#   'apellido': 'Miller',
#   'email': 'ymacdonald@example.com',
#   'direccion': '2021 Christopher Views Apt. 933\nJessicaburgh, MP 92317'},
#  {'nombre': 'Lisa Wade',
#   'apellido': 'Warren',
#   'email': 'romerosandra@example.org',
#   'direccion': '92279 Anderson Cape\nAnthonyberg, WV 57066'},
#  {'nombre': 'Ernest Williamson',
#   'apellido': 'Wilson',
#   'email': 'patricia96@example.net',
#   'direccion': '5150 John Ports Apt. 922\nSouth Michellefort, AL 54356'},
#  {'nombre': 'Victor Payne',
#   'apellido': 'Keller',
#   'email': 'carol60@example.com',
#   'direccion': 'PSC 4408, Box 1270\nAPO AA 20988'},
#  {'nombre': 'Jason Herrera',
#   'apellido': 'Watts',
#   'email': 'zdean@example.com',
#   'direccion': '27836 Andrew Square\nPort Mitchell, AZ 22927'},
#  {'nombre': 'Daniel Miranda',
#   'apellido': 'Mejia',
#   'email': 'fcervantes@example.org',
#   'direccion': '3471 Tran Via\nPort Jordan, CA 43319'},
#  {'nombre': 'Ronald Crawford',
#   'apellido': 'Perry',
#   'email': 'brooke57@example.com',
#   'direccion': '218 Adam Loop\nPort Grace, MO 15591'},
#  {'nombre': 'Victoria Green',
#   'apellido': 'Walker',
#   'email': 'rachel82@example.com',
#   'direccion': '40591 Zachary Haven\nStevensville, ND 32793'},
#  {'nombre': 'Jose Meza',
#   'apellido': 'Jones',
#   'email': 'vellis@example.com',
#   'direccion': '26025 Mcclure Dam\nSouth Ronaldland, MD 68615'},
#  {'nombre': 'Kathryn Reyes',
#   'apellido': 'Ferguson',
#   'email': 'bskinner@example.com',
#   'direccion': '90498 Scott Unions\nLake Leah, CA 90711'},
#  {'nombre': 'Kenneth Davila',
#   'apellido': 'Gaines',
#   'email': 'mwilcox@example.net',
#   'direccion': '0416 Rebecca Shoals Apt. 200\nWilsonton, OK 88830'},
#  {'nombre': 'Michael Sanchez',
#   'apellido': 'Brown',
#   'email': 'lauren31@example.net',
#   'direccion': '5814 Mcdonald Springs\nJessicaborough, AZ 62444'},
#  {'nombre': 'Charles Hopkins',
#   'apellido': 'Bryant',
#   'email': 'randerson@example.net',
#   'direccion': '9856 Brown Cape Suite 391\nSusanton, NV 71078'},
#  {'nombre': 'Kelsey Brooks',
#   'apellido': 'Williams',
#   'email': 'davidorr@example.net',
#   'direccion': '1613 Johnson Drive\nEthanville, PW 73986'},
#  {'nombre': 'Brian Hernandez',
#   'apellido': 'Martinez',
#   'email': 'tgonzalez@example.net',
#   'direccion': '44688 Shawn Vista Suite 565\nNorth William, LA 17269'},
#  {'nombre': 'Steven Adams',
#   'apellido': 'Butler',
#   'email': 'stoneshaun@example.org',
#   'direccion': '4119 Tracy Ford\nWest Andrewland, NH 88912'},
#  {'nombre': 'Jonathan Murphy',
#   'apellido': 'Smith',
#   'email': 'sallymathis@example.com',
#   'direccion': '7939 Hensley Curve Apt. 166\nBellmouth, NY 17643'},
#  {'nombre': 'Mark Willis',
#   'apellido': 'Hubbard',
#   'email': 'laura38@example.org',
#   'direccion': 'Unit 4406 Box 1439\nDPO AP 22046'},
#  {'nombre': 'Joanne Harmon',
#   'apellido': 'Carter',
#   'email': 'romerolindsay@example.com',
#   'direccion': '078 Lauren Tunnel Suite 950\nLake John, AS 15357'},
#  {'nombre': 'Cheryl Zavala',
#   'apellido': 'Campbell',
#   'email': 'pfletcher@example.org',
#   'direccion': '0385 Porter Place\nPort Tiffany, WY 83607'},
#  {'nombre': 'Autumn Quinn',
#   'apellido': 'Davis',
#   'email': 'rojasbradley@example.com',
#   'direccion': 'Unit 9417 Box 2799\nDPO AP 39648'},
#  {'nombre': 'Lisa Baker',
#   'apellido': 'Hayes',
#   'email': 'christophertran@example.org',
#   'direccion': '7488 Chen Road\nPort Donnaville, IA 45772'},
#  {'nombre': 'Terri Ingram',
#   'apellido': 'Smith',
#   'email': 'rochamichael@example.org',
#   'direccion': '53564 Martin Wall\nWest Allison, MO 95669'},
#  {'nombre': 'Mary Martinez',
#   'apellido': 'Moses',
#   'email': 'ilopez@example.org',
#   'direccion': '3459 Baker Trafficway\nHerreraburgh, NJ 72482'},
#  {'nombre': 'Michael Adams',
#   'apellido': 'Glover',
#   'email': 'kbrown@example.org',
#   'direccion': 'Unit 3122 Box 4700\nDPO AP 88547'},
#  {'nombre': 'Erica Collins',
#   'apellido': 'Spencer',
#   'email': 'edward78@example.com',
#   'direccion': '305 Long Squares\nJohnsonland, SD 35989'},
#  {'nombre': 'Kerry Gill',
#   'apellido': 'Beard',
#   'email': 'everettkristine@example.net',
#   'direccion': '80087 Craig Mission Apt. 920\nEast Dianaview, NE 80676'},
#  {'nombre': 'Carlos Holloway',
#   'apellido': 'Mitchell',
#   'email': 'krice@example.org',
#   'direccion': 'USNS Sullivan\nFPO AE 40735'},
#  {'nombre': 'Mr. John Rice',
#   'apellido': 'Cunningham',
#   'email': 'david56@example.org',
#   'direccion': '5883 George Station\nNorth Davidstad, UT 10360'},
#  {'nombre': 'Susan Herrera',
#   'apellido': 'Wilson',
#   'email': 'oscarjackson@example.net',
#   'direccion': '72442 Jonathan Isle\nSouth Joshuaborough, AR 32172'},
#  {'nombre': 'Dalton Martin',
#   'apellido': 'Hill',
#   'email': 'coreyfriedman@example.net',
#   'direccion': '79589 Hahn Knoll\nNew Maria, MS 18100'},
#  {'nombre': 'Matthew Carroll',
#   'apellido': 'Day',
#   'email': 'riddledouglas@example.com',
#   'direccion': '6193 April Centers\nPort Davidburgh, AZ 75573'},
#  {'nombre': 'Jessica Oconnor',
#   'apellido': 'Hernandez',
#   'email': 'parkerangel@example.com',
#   'direccion': '90861 Aguilar Knolls\nLake Nicholaston, GU 67607'},
#  {'nombre': 'Diane White',
#   'apellido': 'Ryan',
#   'email': 'qcalderon@example.com',
#   'direccion': '65032 Christina Fields\nLake Julie, RI 03055'},
#  {'nombre': 'David Burns',
#   'apellido': 'Navarro',
#   'email': 'qbryan@example.org',
#   'direccion': 'Unit 1279 Box 5172\nDPO AP 86803'},
#  {'nombre': 'Caitlin Wolfe',
#   'apellido': 'Mejia',
#   'email': 'abigailthomas@example.net',
#   'direccion': '7024 Hanson Port\nSarahview, NY 35893'},
#  {'nombre': 'Lisa Alexander',
#   'apellido': 'Ramirez',
#   'email': 'willisrobert@example.com',
#   'direccion': '94611 James Lock Apt. 338\nBrandytown, OH 30810'},
#  {'nombre': 'David Clark',
#   'apellido': 'Li',
#   'email': 'sarias@example.com',
#   'direccion': '025 Brian Camp Apt. 084\nEast Paigebury, IA 83375'},
#  {'nombre': 'Paul Garrett',
#   'apellido': 'Smith',
#   'email': 'keithjulia@example.org',
#   'direccion': '842 Crane Keys\nWest Spencerville, MH 07729'},
#  {'nombre': 'Holly Davis',
#   'apellido': 'Gonzalez',
#   'email': 'simsyesenia@example.com',
#   'direccion': '95821 Carr Common Suite 496\nAtkinsonside, PR 88130'},
#  {'nombre': 'Patricia Smith',
#   'apellido': 'Gardner',
#   'email': 'julie90@example.com',
#   'direccion': 'PSC 9234, Box 3874\nAPO AA 45262'},
#  {'nombre': 'Phillip Blake',
#   'apellido': 'Mathis',
#   'email': 'xnolan@example.org',
#   'direccion': '410 Weaver Common Suite 669\nPenningtontown, WY 88580'},
#  {'nombre': 'Douglas Hamilton',
#   'apellido': 'Rodriguez',
#   'email': 'yvonnedavis@example.com',
#   'direccion': '8641 Sanders Gardens\nEast Margaret, NV 42191'},
#  {'nombre': 'Donald Brown',
#   'apellido': 'Woods',
#   'email': 'rodriguezdeanna@example.net',
#   'direccion': '53310 Debbie Garden\nSharonshire, MA 70471'},
#  {'nombre': 'Alan Mckay',
#   'apellido': 'Hunter',
#   'email': 'karen95@example.org',
#   'direccion': '332 Kenneth Field Suite 835\nSamuelmouth, OH 32600'},
#  {'nombre': 'Allison Williams',
#   'apellido': 'Jones',
#   'email': 'ricardo47@example.com',
#   'direccion': '27482 Rachel Squares Apt. 747\nEast Robert, MN 41203'},
#  {'nombre': 'George Mills',
#   'apellido': 'Grant',
#   'email': 'hvalentine@example.net',
#   'direccion': '17911 Thompson Motorway Suite 630\nRoseberg, OK 09476'},
#  {'nombre': 'James Pollard',
#   'apellido': 'Jones',
#   'email': 'bmcdaniel@example.org',
#   'direccion': '52455 Elliott Flat Apt. 543\nRobinsonhaven, AL 14012'},
#  {'nombre': 'Ryan Fletcher',
#   'apellido': 'Bennett',
#   'email': 'sarahlara@example.com',
#   'direccion': '8430 George Turnpike\nBrandonview, AS 36836'},
#  {'nombre': 'Jason Ward',
#   'apellido': 'Clark',
#   'email': 'kristin17@example.org',
#   'direccion': '93588 Jasmine Key\nEast Denisebury, DC 57910'},
#  {'nombre': 'Kelly Clark',
#   'apellido': 'Garcia',
#   'email': 'fredspencer@example.net',
#   'direccion': '379 Anderson Trace Apt. 854\nNorth Thomas, IN 47918'},
#  {'nombre': 'Tammy Combs MD',
#   'apellido': 'Rogers',
#   'email': 'patriciahughes@example.net',
#   'direccion': '1604 Martin Burgs Apt. 475\nStephensfort, SC 01611'},
#  {'nombre': 'Eric Anderson',
#   'apellido': 'Wright',
#   'email': 'ptate@example.net',
#   'direccion': '7479 Wells Fields\nNorth Connorshire, TN 59617'},
#  {'nombre': 'Phillip Burke',
#   'apellido': 'Joseph',
#   'email': 'mackerin@example.org',
#   'direccion': '4118 Graham Union Suite 609\nLake Gailborough, MN 10024'},
#  {'nombre': 'Anthony Butler',
#   'apellido': 'Morton',
#   'email': 'jwarner@example.com',
#   'direccion': '150 Cruz Center Apt. 183\nWest Catherine, GU 68108'},
#  {'nombre': 'John Miller',
#   'apellido': 'Hughes',
#   'email': 'mpadilla@example.org',
#   'direccion': '91526 Pamela Inlet Suite 594\nOconnellburgh, OR 42437'},
#  {'nombre': 'Katie Reynolds',
#   'apellido': 'Martinez',
#   'email': 'heatherevans@example.net',
#   'direccion': '17197 Harris Stravenue\nNew Sarahfurt, WA 67280'},
#  {'nombre': 'Rhonda Thomas',
#   'apellido': 'Koch',
#   'email': 'anthonyparker@example.com',
#   'direccion': '167 Wilson Valley\nBrianborough, PR 63540'},
#  {'nombre': 'Melissa Hunter',
#   'apellido': 'Palmer',
#   'email': 'rrichards@example.com',
#   'direccion': '649 Brittney Forest\nPort Tina, DE 18132'},
#  {'nombre': 'Rebecca Shepherd',
#   'apellido': 'Hawkins',
#   'email': 'courtney60@example.org',
#   'direccion': 'USS Blackburn\nFPO AE 68249'},
#  {'nombre': 'Steven Robinson',
#   'apellido': 'Sanchez',
#   'email': 'elizabeth50@example.com',
#   'direccion': '421 Gray Island\nSouth Dennis, MN 26645'},
#  {'nombre': 'Theresa Scott',
#   'apellido': 'House',
#   'email': 'mcphersonpeter@example.org',
#   'direccion': '494 Ramos Point Apt. 411\nDanielshire, MT 48600'},
#  {'nombre': 'Kyle Steele',
#   'apellido': 'Green',
#   'email': 'kwilson@example.org',
#   'direccion': '69287 Daniel Run Suite 264\nDavidville, PW 06132'},
#  {'nombre': 'Susan Sanchez',
#   'apellido': 'Meza',
#   'email': 'mgardner@example.com',
#   'direccion': '3452 Rodney Turnpike Apt. 400\nJacobfort, MH 42476'},
#  {'nombre': 'Sonya English',
#   'apellido': 'Martinez',
#   'email': 'lovemichelle@example.net',
#   'direccion': '83492 Douglas Ferry Apt. 090\nRandystad, FL 91152'},
#  {'nombre': 'Robert Schmitt',
#   'apellido': 'Johnson',
#   'email': 'jfranklin@example.com',
#   'direccion': '732 Gregory Path Suite 238\nKimport, KS 49781'},
#  {'nombre': 'Bridget Anderson',
#   'apellido': 'Roberts',
#   'email': 'uramos@example.org',
#   'direccion': '663 Dalton Crossing Apt. 841\nWest Devin, IL 47300'},
#  {'nombre': 'Dustin Williams',
#   'apellido': 'Wilson',
#   'email': 'lindsay72@example.com',
#   'direccion': '710 Jennifer Cliff\nAprilfort, SD 43505'},
#  {'nombre': 'Stephen Lynch',
#   'apellido': 'Wheeler',
#   'email': 'adamskimberly@example.net',
#   'direccion': '3586 Rivera Shore Suite 030\nMarkville, ME 19241'},
#  {'nombre': 'Raymond Green',
#   'apellido': 'Henry',
#   'email': 'tracy68@example.org',
#   'direccion': '7269 Sergio Brook Apt. 697\nWest Shaneville, TN 21618'},
#  {'nombre': 'Maria Harrington',
#   'apellido': 'Snyder',
#   'email': 'emma22@example.net',
#   'direccion': '506 Michael Tunnel Suite 091\nEast David, MH 31464'},
#  {'nombre': 'Nathaniel Hicks',
#   'apellido': 'Wise',
#   'email': 'boonebrenda@example.org',
#   'direccion': '679 Robles Pines\nWest Josephfort, IL 83956'},
#  {'nombre': 'Stephen White',
#   'apellido': 'Stephenson',
#   'email': 'courtney91@example.net',
#   'direccion': 'Unit 8429 Box 9512\nDPO AE 15708'},
#  {'nombre': 'Jessica Castro',
#   'apellido': 'Moyer',
#   'email': 'maryhall@example.net',
#   'direccion': '357 Cole Course\nSampsonberg, PW 08876'},
#  {'nombre': 'Christine Fernandez',
#   'apellido': 'Gilbert',
#   'email': 'thomasjose@example.net',
#   'direccion': '8057 Chang Lodge\nEast Amymouth, NH 32261'},
#  {'nombre': 'Luke Reynolds',
#   'apellido': 'White',
#   'email': 'georgekim@example.org',
#   'direccion': '251 Tricia Mill Suite 357\nAngelafurt, NC 16731'},
#  {'nombre': 'Shane Sampson',
#   'apellido': 'Norris',
#   'email': 'kimberly88@example.net',
#   'direccion': '082 Stafford Stream Apt. 449\nNorth April, IN 17976'},
#  {'nombre': 'Daniel Jackson',
#   'apellido': 'Hartman',
#   'email': 'anitaponce@example.org',
#   'direccion': '66462 Cole Trace\nLivingstonstad, TX 85662'},
#  {'nombre': 'Miss Kelly Mckenzie',
#   'apellido': 'Myers',
#   'email': 'ohall@example.org',
#   'direccion': '88887 Tara Island\nJohnsonview, OH 33374'},
#  {'nombre': 'Kayla Bell',
#   'apellido': 'Aguilar',
#   'email': 'diana18@example.com',
#   'direccion': '732 Pace Point\nLake Justinmouth, WI 43757'},
#  {'nombre': 'Jane Palmer',
#   'apellido': 'Parks',
#   'email': 'jameswilson@example.com',
#   'direccion': '72243 Nunez Mill\nNew Heidishire, TN 09237'},
#  {'nombre': 'James Chandler',
#   'apellido': 'Adams',
#   'email': 'joshuawilliams@example.com',
#   'direccion': '904 York Extension Suite 915\nNorth Angelaview, CT 94218'},
#  {'nombre': 'Michelle Wall',
#   'apellido': 'Booth',
#   'email': 'lball@example.net',
#   'direccion': '8003 Kathleen Street Suite 881\nWest Robertside, KS 67555'},
#  {'nombre': 'Anthony Johnson',
#   'apellido': 'Bennett',
#   'email': 'kimberlydiaz@example.com',
#   'direccion': '552 Eduardo Dale Apt. 208\nRacheltown, PW 56888'},
#  {'nombre': 'Terri Lopez',
#   'apellido': 'Hernandez',
#   'email': 'osborneluis@example.com',
#   'direccion': 'Unit 8209 Box 9395\nDPO AE 86690'},
#  {'nombre': 'Nicholas Castillo',
#   'apellido': 'Taylor',
#   'email': 'natasha04@example.net',
#   'direccion': 'PSC 6234, Box 2086\nAPO AP 11213'},
#  {'nombre': 'Roberto Sandoval',
#   'apellido': 'Mueller',
#   'email': 'colleenparker@example.com',
#   'direccion': 'PSC 2929, Box 4068\nAPO AP 75304'},
#  {'nombre': 'Maureen Smith',
#   'apellido': 'King',
#   'email': 'zharper@example.org',
#   'direccion': '3792 Christina Spurs\nKingstad, OH 38815'},
#  {'nombre': 'Christian Smith',
#   'apellido': 'Gonzalez',
#   'email': 'rmiles@example.net',
#   'direccion': '04859 Rhonda Skyway\nSouth Patriciabury, CT 41179'},
#  {'nombre': 'Christopher Jacobs',
#   'apellido': 'Jackson',
#   'email': 'johnbrown@example.com',
#   'direccion': '0981 Nelson Villages\nEast Donnashire, PA 57326'},
#  {'nombre': 'Kelly Morris',
#   'apellido': 'Cain',
#   'email': 'walkerjonathan@example.com',
#   'direccion': '40741 Mclean Haven Apt. 993\nKarenfurt, RI 62896'},
#  {'nombre': 'Patricia Pope',
#   'apellido': 'Johnson',
#   'email': 'moorejavier@example.net',
#   'direccion': '587 Ortiz Plaza Apt. 898\nJordanfurt, NV 95864'},
#  {'nombre': 'Johnny Ramirez',
#   'apellido': 'Ellis',
#   'email': 'rhonda49@example.com',
#   'direccion': '30394 Brandon Lake Apt. 213\nAlexport, NV 39065'},
#  {'nombre': 'Timothy Bond',
#   'apellido': 'Gomez',
#   'email': 'william13@example.com',
#   'direccion': '655 Anthony Junctions Suite 050\nFosterville, MN 61043'},
#  {'nombre': 'Sharon Lynch',
#   'apellido': 'Conley',
#   'email': 'lorisanchez@example.org',
#   'direccion': 'PSC 1912, Box 2757\nAPO AP 15165'},
#  {'nombre': 'Kimberly Figueroa',
#   'apellido': 'Cuevas',
#   'email': 'amitchell@example.org',
#   'direccion': '754 William Square\nDebrafurt, NE 34369'},
#  {'nombre': 'Kathryn Nguyen',
#   'apellido': 'Garcia',
#   'email': 'benjaminrichardson@example.org',
#   'direccion': '732 Ramirez Loaf Suite 882\nParsonsborough, IA 81816'},
#  {'nombre': 'Zachary Hughes',
#   'apellido': 'Navarro',
#   'email': 'byrdmichael@example.org',
#   'direccion': '5181 Rhonda Squares\nHoland, IL 85023'},
#  {'nombre': 'Matthew Diaz',
#   'apellido': 'Thomas',
#   'email': 'susan03@example.org',
#   'direccion': '140 Jim Track Apt. 629\nWest Michael, NM 61599'},
#  {'nombre': 'Matthew Robinson',
#   'apellido': 'Buchanan',
#   'email': 'morrisyesenia@example.org',
#   'direccion': '5512 Valdez Extensions Apt. 578\nKimberlyport, HI 16761'},
#  {'nombre': 'Dale Cox',
#   'apellido': 'Clark',
#   'email': 'hbishop@example.com',
#   'direccion': '383 Raymond Freeway\nWillisborough, ID 60858'},
#  {'nombre': 'Brittany Burke',
#   'apellido': 'Price',
#   'email': 'salazarcalvin@example.org',
#   'direccion': '51007 Roberson Orchard Apt. 984\nMasonland, KY 86614'},
#  {'nombre': 'Amanda Rivera',
#   'apellido': 'Cooley',
#   'email': 'riosrobert@example.net',
#   'direccion': '5726 Cole Garden\nLake Donaldborough, HI 16672'},
#  {'nombre': 'Blake Dixon',
#   'apellido': 'Banks',
#   'email': 'wallacevincent@example.org',
#   'direccion': '90820 Johnson Curve\nNew Pennyport, KS 37934'},
#  {'nombre': 'Sean Morales',
#   'apellido': 'Mccarty',
#   'email': 'jennifermclaughlin@example.com',
#   'direccion': '385 Jeffrey Mountains\nDavidmouth, NM 16544'},
#  {'nombre': 'Matthew Calhoun',
#   'apellido': 'Randall',
#   'email': 'heathermoyer@example.com',
#   'direccion': 'Unit 6629 Box 6092\nDPO AA 89379'},
#  {'nombre': 'Jerome Warner',
#   'apellido': 'Anderson',
#   'email': 'deannapalmer@example.com',
#   'direccion': '8404 Munoz Gateway\nRobertborough, CT 60727'},
#  {'nombre': 'Amanda Garrett',
#   'apellido': 'Howell',
#   'email': 'timothybrown@example.com',
#   'direccion': '20604 Bryce Squares\nSouth Gabrielle, MI 82763'},
#  {'nombre': 'Joel Vargas',
#   'apellido': 'Torres',
#   'email': 'prattjoshua@example.com',
#   'direccion': 'USNS Ramirez\nFPO AP 29147'},
#  {'nombre': 'Mark Davidson',
#   'apellido': 'Watkins',
#   'email': 'johnsmith@example.org',
#   'direccion': '012 Angela Cape\nEast Robertview, PW 66185'},
#  {'nombre': 'Megan Jones',
#   'apellido': 'Cooley',
#   'email': 'manuel35@example.org',
#   'direccion': '074 Christian Port\nPort Kristin, NE 72204'},
#  {'nombre': 'Carolyn Daniel',
#   'apellido': 'Stephens',
#   'email': 'gregory97@example.net',
#   'direccion': '2413 Logan Grove\nPort Stephen, ND 45332'},
#  {'nombre': 'Don Hicks',
#   'apellido': 'Walker',
#   'email': 'josephwilson@example.net',
#   'direccion': '504 Wallace Expressway\nStephenside, CT 13210'},
#  {'nombre': 'Jeremy Jackson',
#   'apellido': 'Dickson',
#   'email': 'jessicamann@example.com',
#   'direccion': '57439 Kyle Drive Suite 609\nBellhaven, AS 30025'},
#  {'nombre': 'Paul Davis',
#   'apellido': 'Cuevas',
#   'email': 'phillip06@example.net',
#   'direccion': '1156 Farley Coves Apt. 599\nLake Ryanbury, DE 75307'},
#  {'nombre': 'Christina Neal',
#   'apellido': 'Torres',
#   'email': 'ryan05@example.org',
#   'direccion': '7295 Davis Plains\nLynnton, MA 92895'},
#  {'nombre': 'Amy Lam',
#   'apellido': 'Ball',
#   'email': 'rodriguezjoseph@example.org',
#   'direccion': '738 Joyce Mall\nJoelburgh, GA 53702'},
#  {'nombre': 'Christopher Carrillo',
#   'apellido': 'Vazquez',
#   'email': 'michele39@example.org',
#   'direccion': '12640 Joel Mission\nRobinsonside, TX 52203'},
#  {'nombre': 'Frank Gonzales',
#   'apellido': 'Hall',
#   'email': 'wendygriffin@example.net',
#   'direccion': '3470 Monica Trail\nBrownmouth, AL 74607'},
#  {'nombre': 'Michelle Hogan',
#   'apellido': 'Campbell',
#   'email': 'justinfry@example.net',
#   'direccion': '514 Stewart Fork\nNew Chad, MN 16519'},
#  {'nombre': 'Stephanie Garcia',
#   'apellido': 'Barton',
#   'email': 'freemanalexander@example.com',
#   'direccion': '66938 Schmitt Unions\nLoriton, OK 94156'},
#  {'nombre': 'Brandy Reed',
#   'apellido': 'Miller',
#   'email': 'alison20@example.com',
#   'direccion': 'USNV Cooper\nFPO AE 61218'},
#  {'nombre': 'Daniel Garner',
#   'apellido': 'Shepard',
#   'email': 'jacksonsharon@example.com',
#   'direccion': '16500 Perry Views\nWest Briannaport, NM 61693'},
#  {'nombre': 'Matthew Miller',
#   'apellido': 'Green',
#   'email': 'lauren61@example.net',
#   'direccion': '7037 Mary Village\nThomasfort, CT 28500'},
#  {'nombre': 'Donna Neal',
#   'apellido': 'Wilson',
#   'email': 'tuckeramanda@example.org',
#   'direccion': '8840 Kimberly Mill Suite 884\nBrettview, ND 52165'},
#  {'nombre': 'Victoria Hicks',
#   'apellido': 'Warren',
#   'email': 'emily87@example.net',
#   'direccion': '98398 Steven Camp\nJosephville, HI 35694'},
#  {'nombre': 'Omar Arnold',
#   'apellido': 'Mcknight',
#   'email': 'elizabeth37@example.org',
#   'direccion': '257 Browning Island Suite 064\nEast Cathyside, ID 34064'},
#  {'nombre': 'Kenneth Murphy',
#   'apellido': 'Rodriguez',
#   'email': 'paul94@example.com',
#   'direccion': '872 Patricia Plaza\nWest Taylor, OR 68003'},
#  {'nombre': 'Erik Velez',
#   'apellido': 'Ward',
#   'email': 'teresa16@example.com',
#   'direccion': '6064 Dustin Light Apt. 635\nSmithhaven, SD 34542'},
#  {'nombre': 'Jennifer Hendricks',
#   'apellido': 'Woodard',
#   'email': 'charles40@example.net',
#   'direccion': '097 Kenneth Locks\nLake Mary, AS 24574'},
#  {'nombre': 'Sandra Johnston',
#   'apellido': 'Watkins',
#   'email': 'lori02@example.org',
#   'direccion': '156 Tiffany Port\nJamesport, ID 74954'},
#  {'nombre': 'Michelle Malone',
#   'apellido': 'Nguyen',
#   'email': 'davidromero@example.net',
#   'direccion': '993 Kayla Centers\nNew Robertborough, PR 94478'},
#  {'nombre': 'Sherri Hanna',
#   'apellido': 'Ewing',
#   'email': 'gdougherty@example.net',
#   'direccion': '802 Teresa Forks\nWeaverport, DE 66953'},
#  {'nombre': 'Justin Jones',
#   'apellido': 'Shaw',
#   'email': 'kristina07@example.net',
#   'direccion': '6122 Dawn Street\nPort Kimberly, IA 98570'},
#  {'nombre': 'Paul Jones',
#   'apellido': 'Reed',
#   'email': 'raykeith@example.net',
#   'direccion': '959 Sherman Harbor Apt. 455\nNorth Gwendolynmouth, NC 11296'},
#  {'nombre': 'Karen Wolfe',
#   'apellido': 'James',
#   'email': 'gmoore@example.org',
#   'direccion': '967 Andrew Rapid Suite 117\nLake Ethanburgh, LA 92825'},
#  {'nombre': 'Janice Clayton',
#   'apellido': 'Simpson',
#   'email': 'walkertammy@example.com',
#   'direccion': '296 Jacqueline Expressway Suite 306\nSouth Karentown, AS 77662'},
#  {'nombre': 'Kelly Parker',
#   'apellido': 'Brown',
#   'email': 'anthony98@example.net',
#   'direccion': '66298 Evans River Suite 274\nWest Taylormouth, AL 41752'},
#  {'nombre': 'Jenna Moore',
#   'apellido': 'Kim',
#   'email': 'jilliangeorge@example.org',
#   'direccion': '3394 Catherine Mountains Apt. 275\nHernandezstad, MS 13598'},
#  {'nombre': 'Mark Moses',
#   'apellido': 'Miller',
#   'email': 'pattersonkayla@example.com',
#   'direccion': '5992 Allen Crossing Suite 918\nNorth Tanya, CA 92494'},
#  {'nombre': 'Marissa Bell',
#   'apellido': 'Evans',
#   'email': 'prodriguez@example.net',
#   'direccion': '3935 Harris Gardens Apt. 195\nLake Elizabethland, TX 18064'},
#  {'nombre': 'Caitlin Mckenzie',
#   'apellido': 'Valenzuela',
#   'email': 'rsanders@example.net',
#   'direccion': '7585 Deborah Rest\nLeonborough, MT 33130'},
#  {'nombre': 'Theresa Taylor',
#   'apellido': 'Salazar',
#   'email': 'gordontamara@example.org',
#   'direccion': '29395 Lopez Drive\nKatherineborough, PA 37205'},
#  {'nombre': 'Raymond Smith',
#   'apellido': 'Harrington',
#   'email': 'wilsonwayne@example.com',
#   'direccion': '567 Griffin Vista\nEdwardsside, ME 08209'},
#  {'nombre': 'Anna Bishop',
#   'apellido': 'Johnson',
#   'email': 'zdurham@example.net',
#   'direccion': '0052 Kathleen Shore Suite 380\nAarontown, FM 88637'},
#  {'nombre': 'Frederick Moore',
#   'apellido': 'Jensen',
#   'email': 'jaredmathis@example.net',
#   'direccion': '8089 Andrew Walks Apt. 339\nCraigville, MS 22765'},
#  {'nombre': 'Melissa Simpson',
#   'apellido': 'Roberts',
#   'email': 'dunnsean@example.net',
#   'direccion': '490 Susan Lodge\nChristinafort, ME 09976'},
#  {'nombre': 'Aaron Hall',
#   'apellido': 'Long',
#   'email': 'simpsondylan@example.org',
#   'direccion': '41009 Taylor Ferry Apt. 674\nSandraside, NV 40055'},
#  {'nombre': 'Erica Davis',
#   'apellido': 'Martin',
#   'email': 'fmorales@example.org',
#   'direccion': '19719 Stephanie Port\nLake Christopherview, OR 67601'},
#  {'nombre': 'David Spence',
#   'apellido': 'Williams',
#   'email': 'paul36@example.net',
#   'direccion': '8583 Wagner Path Suite 161\nNew Andrewmouth, UT 09437'},
#  {'nombre': 'Mathew Zamora',
#   'apellido': 'Garrett',
#   'email': 'sarahharris@example.org',
#   'direccion': '2314 Lisa Hills\nNorth Angel, FL 40116'},
#  {'nombre': 'Donna Neal',
#   'apellido': 'Mcdonald',
#   'email': 'georgenathaniel@example.com',
#   'direccion': '1035 Erika Lakes Apt. 727\nJessicafort, PW 78535'},
#  {'nombre': 'Kathy Oconnor',
#   'apellido': 'Anderson',
#   'email': 'anthony80@example.com',
#   'direccion': '7875 Ray Turnpike\nLake Daleberg, TX 54629'},
#  {'nombre': 'Jonathan Eaton',
#   'apellido': 'Gill',
#   'email': 'nicole51@example.org',
#   'direccion': '0927 Williams Shores\nPort Mark, LA 39987'},
#  {'nombre': 'Joseph Moore',
#   'apellido': 'Parker',
#   'email': 'wholland@example.com',
#   'direccion': '630 Stevens Islands\nWest Amy, MH 38614'},
#  {'nombre': 'Eric Dixon',
#   'apellido': 'Schultz',
#   'email': 'joebailey@example.org',
#   'direccion': '7608 Andersen Locks Apt. 356\nWest Meganburgh, ME 26373'},
#  {'nombre': 'Megan Gordon',
#   'apellido': 'Chung',
#   'email': 'pcastillo@example.net',
#   'direccion': 'USCGC Becker\nFPO AA 03444'},
#  {'nombre': 'Michelle Myers',
#   'apellido': 'Gonzalez',
#   'email': 'rbrown@example.com',
#   'direccion': '186 Barbara Wells Apt. 830\nKeithmouth, SC 11371'},
#  {'nombre': 'Natalie Higgins',
#   'apellido': 'Russell',
#   'email': 'martinezsarah@example.org',
#   'direccion': 'USNS Randall\nFPO AP 21945'},
#  {'nombre': 'Jacob Lyons',
#   'apellido': 'Ochoa',
#   'email': 'helliott@example.com',
#   'direccion': '416 Mark Walk\nSouth Mikeview, KS 57456'},
#  {'nombre': 'Courtney Mcdaniel',
#   'apellido': 'Thomas',
#   'email': 'eedwards@example.org',
#   'direccion': '52527 Hughes Ports Apt. 989\nWest Charlesshire, KS 36038'},
#  {'nombre': 'Christina Johnson',
#   'apellido': 'Marshall',
#   'email': 'christopherrodriguez@example.org',
#   'direccion': '54642 Valerie Prairie Suite 729\nNew Brandon, WY 40568'},
#  {'nombre': 'Trevor Hernandez',
#   'apellido': 'Black',
#   'email': 'fisherkimberly@example.com',
#   'direccion': '4573 Ward Manors\nSouth Omarland, PW 37651'},
#  {'nombre': 'Mr. Cameron Aguirre',
#   'apellido': 'Miller',
#   'email': 'theath@example.com',
#   'direccion': '298 Stuart Wall Suite 849\nNew Rebecca, SD 83185'},
#  {'nombre': 'William Perry',
#   'apellido': 'Young',
#   'email': 'larry89@example.org',
#   'direccion': '042 Evans Tunnel\nSuttonville, NC 31623'},
#  {'nombre': 'Casey Ho',
#   'apellido': 'Austin',
#   'email': 'randerson@example.org',
#   'direccion': '0626 Dougherty Parkway\nCarlosmouth, MP 53988'},
#  {'nombre': 'Desiree Smith',
#   'apellido': 'Hernandez',
#   'email': 'hahndonna@example.org',
#   'direccion': '8889 Ochoa Hills\nNew Barbara, MD 14644'},
#  {'nombre': 'Jonathan Bautista',
#   'apellido': 'Johnson',
#   'email': 'katrinaanderson@example.org',
#   'direccion': '7578 Thomas Heights\nLake Jennifermouth, MA 98764'},
#  {'nombre': 'Renee Gillespie',
#   'apellido': 'Martinez',
#   'email': 'francisking@example.net',
#   'direccion': '8875 Noah Dam Suite 037\nNew Andrea, AS 64164'},
#  {'nombre': 'Michelle Scott',
#   'apellido': 'Jackson',
#   'email': 'martinjillian@example.org',
#   'direccion': 'Unit 9094 Box 7180\nDPO AP 82063'},
#  {'nombre': 'Natalie Williams',
#   'apellido': 'Day',
#   'email': 'zdouglas@example.org',
#   'direccion': '85669 Darius Inlet Apt. 230\nLake Anthonytown, LA 91604'},
#  {'nombre': 'Michelle Ford',
#   'apellido': 'Orozco',
#   'email': 'mcalderon@example.com',
#   'direccion': '76468 Chavez Oval Suite 383\nNorth Jose, NV 67166'},
#  {'nombre': 'Michelle Lee',
#   'apellido': 'Hardy',
#   'email': 'clineelizabeth@example.com',
#   'direccion': '2769 Kristin Point\nNew Williamside, AS 26006'},
#  {'nombre': 'Melissa Lopez',
#   'apellido': 'Allen',
#   'email': 'ymyers@example.com',
#   'direccion': '375 Vasquez Divide\nSouth Debraview, PW 68656'},
#  {'nombre': 'John Klein',
#   'apellido': 'Hamilton',
#   'email': 'anthonybarton@example.net',
#   'direccion': '01311 Dana Loop\nPort Jennifer, GA 91979'},
#  {'nombre': 'William Jackson',
#   'apellido': 'Collins',
#   'email': 'riggsandrew@example.org',
#   'direccion': '711 Brenda Club Suite 023\nWalkerberg, NY 09336'},
#  {'nombre': 'Randy Wright',
#   'apellido': 'Wade',
#   'email': 'amykeller@example.org',
#   'direccion': 'PSC 7066, Box 0223\nAPO AA 12350'},
#  {'nombre': 'Patrick Barker',
#   'apellido': 'Lyons',
#   'email': 'deanrebecca@example.net',
#   'direccion': '72241 Lowery Ports\nLowefurt, DE 10734'},
#  {'nombre': 'Michael Wyatt',
#   'apellido': 'David',
#   'email': 'asanchez@example.org',
#   'direccion': '09175 Mason Grove Apt. 933\nNorth Rachelport, NJ 49653'},
#  {'nombre': 'Jason Crosby',
#   'apellido': 'Ray',
#   'email': 'juanflores@example.net',
#   'direccion': '7902 Samuel Point Suite 229\nPort Justinborough, LA 82175'},
#  {'nombre': 'Christine James',
#   'apellido': 'Walker',
#   'email': 'kruegertiffany@example.net',
#   'direccion': '6724 Anna Path\nNew Jose, MT 97424'},
#  {'nombre': 'Teresa Burgess',
#   'apellido': 'Dean',
#   'email': 'carolynvargas@example.org',
#   'direccion': '5146 Bruce Shoal Apt. 062\nJonesville, GU 63926'},
#  {'nombre': 'Ashley Park',
#   'apellido': 'Phillips',
#   'email': 'sandracohen@example.net',
#   'direccion': '247 Powers Shoals Apt. 428\nPort Nathanielside, OR 95539'},
#  {'nombre': 'Andre Henderson',
#   'apellido': 'Jackson',
#   'email': 'morganlewis@example.org',
#   'direccion': '859 Christian View Suite 787\nNorth Mary, HI 73602'},
#  {'nombre': 'Christine Jackson',
#   'apellido': 'Chavez',
#   'email': 'moorebilly@example.net',
#   'direccion': 'PSC 1382, Box 5644\nAPO AA 81434'},
#  {'nombre': 'Richard Hernandez',
#   'apellido': 'Bush',
#   'email': 'mitchellrichard@example.com',
#   'direccion': '1357 Ryan Station\nTimothyside, NV 70811'},
#  {'nombre': 'Arthur Thornton',
#   'apellido': 'Jimenez',
#   'email': 'tyler78@example.org',
#   'direccion': '69188 Eugene Lane Suite 435\nPort Tylermouth, MS 29654'},
#  {'nombre': 'Randy Wilson',
#   'apellido': 'Owen',
#   'email': 'brianna88@example.net',
#   'direccion': '105 Ramirez Common\nLawrenceburgh, LA 77425'},
#  {'nombre': 'Amber Smith',
#   'apellido': 'King',
#   'email': 'prestonserrano@example.org',
#   'direccion': '518 Elijah Landing\nPort Aaronside, OR 40022'},
#  {'nombre': 'Kendra Cervantes',
#   'apellido': 'Ballard',
#   'email': 'jacksonrobert@example.net',
#   'direccion': 'PSC 3289, Box 9908\nAPO AA 45295'},
#  {'nombre': 'Lauren Stone',
#   'apellido': 'Cabrera',
#   'email': 'joanndouglas@example.com',
#   'direccion': '4944 Joshua Dam\nLeeburgh, ND 54633'},
#  {'nombre': 'Donna Wilson',
#   'apellido': 'Ramos',
#   'email': 'lrose@example.org',
#   'direccion': '6155 Jacob Lock\nBrennanton, MO 23034'},
#  {'nombre': 'Michael James',
#   'apellido': 'Colon',
#   'email': 'stephen75@example.net',
#   'direccion': '88923 John Throughway\nMartinton, NY 59452'},
#  {'nombre': 'Willie Johnson',
#   'apellido': 'Price',
#   'email': 'jillking@example.com',
#   'direccion': '04829 Dunn Groves\nPort Ashley, NV 71513'},
#  {'nombre': 'Carly Morales',
#   'apellido': 'Singh',
#   'email': 'zramirez@example.net',
#   'direccion': 'USNS Martinez\nFPO AP 82211'},
#  {'nombre': 'Diana Hughes',
#   'apellido': 'Fernandez',
#   'email': 'mckinneyrussell@example.org',
#   'direccion': 'PSC 8275, Box 2644\nAPO AP 93820'},
#  {'nombre': 'Jordan Williams',
#   'apellido': 'Estrada',
#   'email': 'fletcherlaura@example.net',
#   'direccion': '7028 Cindy Squares\nPort Jaredland, NC 95965'},
#  {'nombre': 'Robert Robinson',
#   'apellido': 'Larsen',
#   'email': 'nicole40@example.com',
#   'direccion': '0545 Chad Well\nWest Robertmouth, PW 84190'},
#  {'nombre': 'Charles Duke',
#   'apellido': 'Bradford',
#   'email': 'heather64@example.net',
#   'direccion': 'Unit 3504 Box 0850\nDPO AA 87982'},
#  {'nombre': 'Mr. Raymond Wagner',
#   'apellido': 'Martin',
#   'email': 'rhaas@example.org',
#   'direccion': '9045 Lowe Bridge\nManningchester, MS 08819'},
#  {'nombre': 'Karen Poole',
#   'apellido': 'Garcia',
#   'email': 'zjarvis@example.org',
#   'direccion': '43440 Martin Drive\nJoseton, MN 30909'},
#  {'nombre': 'Mark Banks',
#   'apellido': 'Rodriguez',
#   'email': 'sethfreeman@example.org',
#   'direccion': '72393 Schroeder Well Apt. 957\nMeyersmouth, MO 95504'},
#  {'nombre': 'Latoya Campbell',
#   'apellido': 'Sanchez',
#   'email': 'mcbridelogan@example.net',
#   'direccion': '386 Jenna Dam Apt. 496\nNorth Mirandafurt, TX 99060'},
#  {'nombre': 'Eric Weiss',
#   'apellido': 'Smith',
#   'email': 'shawnwashington@example.org',
#   'direccion': '67788 Bartlett Radial Apt. 153\nNew Zacharyport, VT 31250'},
#  {'nombre': 'Nathan Reed',
#   'apellido': 'Rhodes',
#   'email': 'rmartinez@example.com',
#   'direccion': '529 Tammy Corners Apt. 413\nToniport, FL 67191'},
#  {'nombre': 'Daniel Chase',
#   'apellido': 'Lewis',
#   'email': 'guerrerosarah@example.org',
#   'direccion': '30493 Douglas Causeway Apt. 679\nWest Bridgetview, NH 89118'},
#  {'nombre': 'Mario Willis',
#   'apellido': 'Gibson',
#   'email': 'vhernandez@example.com',
#   'direccion': '06995 Mcdowell Land\nSinghberg, SC 18751'},
#  {'nombre': 'Tracey Walker',
#   'apellido': 'Waters',
#   'email': 'morganamber@example.com',
#   'direccion': '5880 Wilson Throughway\nNorth Matthewfurt, FL 12362'},
#  {'nombre': 'Christopher Jones',
#   'apellido': 'Poole',
#   'email': 'daniel74@example.com',
#   'direccion': '152 Baker Mall Apt. 756\nHillview, UT 11098'},
#  {'nombre': 'Gary Webb',
#   'apellido': 'Trujillo',
#   'email': 'biancabray@example.net',
#   'direccion': '96665 Nguyen Branch\nNew Derek, VT 34903'},
#  {'nombre': 'Raymond Gomez',
#   'apellido': 'Morrison',
#   'email': 'jfrank@example.org',
#   'direccion': '7608 Patel Extension\nMendezville, HI 31906'},
#  {'nombre': 'William Ayala',
#   'apellido': 'Gilbert',
#   'email': 'christophermartin@example.com',
#   'direccion': 'PSC 7076, Box 9547\nAPO AE 47938'},
#  {'nombre': 'Nicholas Willis',
#   'apellido': 'Alvarez',
#   'email': 'angela52@example.org',
#   'direccion': '611 Nathaniel Ports Apt. 164\nAcevedoville, TN 95621'},
#  {'nombre': 'Suzanne Scott',
#   'apellido': 'Sullivan',
#   'email': 'camposdavid@example.net',
#   'direccion': '9343 Melanie Garden\nPatrickport, NV 37905'},
#  {'nombre': 'Matthew Miller',
#   'apellido': 'Conway',
#   'email': 'kathleen68@example.net',
#   'direccion': '7556 Harvey Stream Apt. 448\nBrianport, MO 10851'},
#  {'nombre': 'Jessica Leon',
#   'apellido': 'Richardson',
#   'email': 'brendaenglish@example.net',
#   'direccion': '90746 Jacqueline Springs Apt. 992\nNew Lydiahaven, MH 82097'},
#  {'nombre': 'James Foster',
#   'apellido': 'Howard',
#   'email': 'aaronbush@example.org',
#   'direccion': '7051 Floyd Well\nPort Jessica, UT 83074'},
#  {'nombre': 'Chelsea Nelson',
#   'apellido': 'Jones',
#   'email': 'kruegertammy@example.com',
#   'direccion': '9025 William Dale Apt. 064\nMckayfurt, WI 90733'},
#  {'nombre': 'Andrew Cowan',
#   'apellido': 'Shah',
#   'email': 'ianbarajas@example.net',
#   'direccion': '3952 Fred Extension Suite 241\nNorth Markmouth, HI 83983'},
#  {'nombre': 'Charles Lopez',
#   'apellido': 'Torres',
#   'email': 'donnahuff@example.org',
#   'direccion': '6266 Murphy Causeway\nNorth Breanna, AZ 24606'},
#  {'nombre': 'Stephen Bryant',
#   'apellido': 'Jordan',
#   'email': 'jasonkelly@example.com',
#   'direccion': '9366 Eric Junction\nFergusonbury, CO 35045'},
#  {'nombre': 'Kimberly Holloway',
#   'apellido': 'Walters',
# ...
#   'apellido': 'Mitchell',
#   'email': 'kaitlynfarrell@example.com',
#   'direccion': '7373 Francisco Parkway Suite 870\nWest Paulstad, GU 92490'},
#  {'nombre': 'Lisa Foster',
#   'apellido': 'Villarreal',
#   'email': 'danielle38@example.net',
#   'direccion': '996 Sandoval Knoll\nNorth Ashleyborough, MN 49878'},
#  {'nombre': 'Casey Johnson',
#   'apellido': 'Underwood',
#   'email': 'olsenjacob@example.org',
#   'direccion': '15956 Cline Orchard Apt. 053\nAlanside, MI 37660'},
#  {'nombre': 'Haley Mclean MD',
#   'apellido': 'Clark',
#   'email': 'davidgarcia@example.org',
#   'direccion': 'USNS King\nFPO AA 84871'},
#  {'nombre': 'Frank Wallace',
#   'apellido': 'Hughes',
#   'email': 'hnewman@example.org',
#   'direccion': '9478 Ross Path Apt. 252\nBarberfurt, VI 57039'},
#  {'nombre': 'Emily Miller',
#   'apellido': 'Rodriguez',
#   'email': 'karenknight@example.com',
#   'direccion': '14921 Gonzalez Springs Suite 269\nLisabury, MS 84750'},
#  {'nombre': 'Tonya Olson',
#   'apellido': 'Lewis',
#   'email': 'watersnicole@example.org',
#   'direccion': '5608 Kristi Shoal Apt. 059\nHoffmanstad, NY 92763'},
#  {'nombre': 'Chad Wright',
#   'apellido': 'Robertson',
#   'email': 'whiteheadharold@example.net',
#   'direccion': '184 Sullivan Divide Suite 698\nHallshire, MS 79886'},
#  {'nombre': 'Kristin Miller',
#   'apellido': 'Wong',
#   'email': 'joseph39@example.net',
#   'direccion': '04142 Stafford Mountains\nMarkchester, PW 43245'},
#  {'nombre': 'Steven Mccall',
#   'apellido': 'Davis',
#   'email': 'richardmegan@example.org',
#   'direccion': '5998 Julia Meadow\nTheresashire, MD 74380'},
#  {'nombre': 'Michael Atkinson',
#   'apellido': 'Long',
#   'email': 'stevensbrian@example.net',
#   'direccion': '63517 Jasmin Avenue Apt. 722\nDonaldsonside, DC 51112'},
#  {'nombre': 'Dalton Gonzalez',
#   'apellido': 'Howell',
#   'email': 'emosley@example.org',
#   'direccion': '040 Ford Trail Apt. 927\nWadeville, MN 67037'},
#  {'nombre': 'Wendy Freeman',
#   'apellido': 'Ortiz',
#   'email': 'leah33@example.com',
#   'direccion': '963 Heather Springs\nPerezside, CA 46724'},
#  {'nombre': 'Charles Obrien',
#   'apellido': 'Thomas',
#   'email': 'cannonyvonne@example.net',
#   'direccion': '049 Rebecca Shoals Apt. 227\nChavezmouth, RI 74641'},
#  {'nombre': 'David James',
#   'apellido': 'Flores',
#   'email': 'keithlee@example.com',
#   'direccion': '3899 Andrew Corners Suite 264\nNorth Kylie, MO 17035'},
#  {'nombre': 'William Jones',
#   'apellido': 'Jimenez',
#   'email': 'jacobrogers@example.net',
#   'direccion': '1708 Jason Ports\nAliceshire, MO 47309'},
#  {'nombre': 'Russell Salas',
#   'apellido': 'Jones',
#   'email': 'speterson@example.com',
#   'direccion': '42779 Anthony Glen\nNew Scott, OR 10677'},
#  {'nombre': 'Laura Sanchez',
#   'apellido': 'Vasquez',
#   'email': 'sharon10@example.com',
#   'direccion': '65419 Stephanie Expressway Apt. 363\nPort Kimberly, IA 33468'},
#  {'nombre': 'Molly Myers',
#   'apellido': 'Brown',
#   'email': 'gallagherallison@example.net',
#   'direccion': '4690 Nicholas Flat Suite 575\nPort Tylerfort, NE 39873'},
#  {'nombre': 'Chelsea Bowman',
#   'apellido': 'Alexander',
#   'email': 'jasonsilva@example.com',
#   'direccion': '89041 Kenneth Island\nLake Johnhaven, AR 80948'},
#  {'nombre': 'Mark Brandt',
#   'apellido': 'Mcdonald',
#   'email': 'sarahlopez@example.net',
#   'direccion': 'PSC 3099, Box 4132\nAPO AA 16393'},
#  {'nombre': 'Mary Roach',
#   'apellido': 'Martinez',
#   'email': 'judy52@example.org',
#   'direccion': '00637 Evans Club Suite 267\nWest Donaldmouth, AL 02503'},
#  {'nombre': 'Heather Berg',
#   'apellido': 'Ramsey',
#   'email': 'ddavis@example.com',
#   'direccion': '8894 Thomas Stream Suite 923\nSouth Kathryn, CA 28626'},
#  {'nombre': 'Jennifer Fuller',
#   'apellido': 'Green',
#   'email': 'zholt@example.org',
#   'direccion': '602 Connie Union Apt. 675\nPort Donna, NM 39273'},
#  {'nombre': 'Rhonda Gonzalez MD',
#   'apellido': 'Romero',
#   'email': 'jeffreymontgomery@example.net',
#   'direccion': '1464 Nicole Hill Apt. 520\nEast Stephanie, OH 93704'},
#  {'nombre': 'Jennifer Bauer',
#   'apellido': 'Beasley',
#   'email': 'kingelizabeth@example.com',
#   'direccion': 'PSC 2786, Box 0291\nAPO AE 11134'},
#  {'nombre': 'Haley Rowe',
#   'apellido': 'Williams',
#   'email': 'framos@example.net',
#   'direccion': '49070 Jasmin Corners Apt. 623\nNorth Craigland, PA 39420'},
#  {'nombre': 'Jenna Sharp',
#   'apellido': 'Bishop',
#   'email': 'rhaynes@example.net',
#   'direccion': '008 Ann Brooks\nSouth Kaitlinfurt, WI 14159'},
#  {'nombre': 'Victor Wang',
#   'apellido': 'Hale',
#   'email': 'njenkins@example.com',
#   'direccion': '9764 Susan Locks\nWest Darrellville, CA 29985'},
#  {'nombre': 'Christopher Gonzales',
#   'apellido': 'Anderson',
#   'email': 'nwalker@example.net',
#   'direccion': '92118 Joshua Rapids Apt. 325\nLarryborough, HI 90455'},
#  {'nombre': 'Carrie Smith',
#   'apellido': 'Smith',
#   'email': 'jholloway@example.org',
#   'direccion': '74814 Erin Ridges Apt. 646\nKristenmouth, SD 60067'},
#  {'nombre': 'Christopher Stevens',
#   'apellido': 'Lowe',
#   'email': 'dawsonsarah@example.com',
#   'direccion': '76693 Sandra Inlet Suite 045\nJamieland, WA 23232'},
#  {'nombre': 'Whitney Curtis',
#   'apellido': 'Blevins',
#   'email': 'catherine03@example.net',
#   'direccion': '36644 Shelby Lake Suite 666\nBarnettfurt, MH 29883'},
#  {'nombre': 'Thomas Reilly',
#   'apellido': 'Scott',
#   'email': 'rebecca96@example.org',
#   'direccion': '6641 Mitchell Village Apt. 917\nSarahstad, PW 42556'},
#  {'nombre': 'Sara Coleman',
#   'apellido': 'Wright',
#   'email': 'charles20@example.net',
#   'direccion': '0982 Mayo Square Suite 611\nLauramouth, NY 83220'},
#  {'nombre': 'Karen White',
#   'apellido': 'Daniels',
#   'email': 'nwatson@example.com',
#   'direccion': '959 Alexandria Parks Apt. 852\nThomasburgh, NC 60348'},
#  {'nombre': 'Amanda Brown',
#   'apellido': 'House',
#   'email': 'darryl12@example.com',
#   'direccion': 'Unit 2513 Box 7333\nDPO AA 62838'},
#  {'nombre': 'Jonathan Smith',
#   'apellido': 'Keller',
#   'email': 'griffithrobert@example.org',
#   'direccion': '51568 Ashley Terrace\nCourtneystad, AK 02791'},
#  {'nombre': 'Robert Barber',
#   'apellido': 'Hill',
#   'email': 'dwatts@example.net',
#   'direccion': '4748 Lopez Overpass\nWilkinsonhaven, SD 87918'},
#  {'nombre': 'Jackie Palmer',
#   'apellido': 'Goodwin',
#   'email': 'hillbrian@example.org',
#   'direccion': '4742 Jones Garden\nSouth Robertberg, LA 11510'},
#  {'nombre': 'Rebecca Alvarez',
#   'apellido': 'Richards',
#   'email': 'scott40@example.com',
#   'direccion': '61719 Timothy Track\nBenitezhaven, DC 13291'},
#  {'nombre': 'Tyler Park',
#   'apellido': 'Jackson',
#   'email': 'poncejodi@example.org',
#   'direccion': '59285 Davis Course Suite 579\nMartinborough, OR 88455'},
#  {'nombre': 'Angela Choi',
#   'apellido': 'Parker',
#   'email': 'ryananna@example.com',
#   'direccion': 'USNV Ballard\nFPO AA 83172'},
#  {'nombre': 'Roberta Brown',
#   'apellido': 'Baker',
#   'email': 'scottjames@example.com',
#   'direccion': '720 Jordan Corner Suite 431\nLake John, AS 77733'},
#  {'nombre': 'Glenn Wagner',
#   'apellido': 'Russell',
#   'email': 'alexandercampbell@example.org',
#   'direccion': '761 Susan Coves\nMatthewbury, IA 93708'},
#  {'nombre': 'James Luna',
#   'apellido': 'Brown',
#   'email': 'wwebb@example.net',
#   'direccion': '6095 John Camp\nBrianbury, CT 85029'},
#  {'nombre': 'Adrian Schmitt',
#   'apellido': 'Cross',
#   'email': 'xhunter@example.net',
#   'direccion': '20322 Lowe Station Suite 778\nMarieborough, VA 20694'},
#  {'nombre': 'Edward Warner',
#   'apellido': 'Finley',
#   'email': 'andreaosborne@example.net',
#   'direccion': '21984 Christopher Fort\nNorth Daniel, MD 77468'},
#  {'nombre': 'Tammy Fitzpatrick',
#   'apellido': 'Sanchez',
#   'email': 'davidhardin@example.net',
#   'direccion': '83457 Robert Divide\nSusanmouth, NJ 57953'},
#  {'nombre': 'Marissa Mccarty',
#   'apellido': 'Hill',
#   'email': 'fjackson@example.org',
#   'direccion': '88701 Kevin Lock\nSamanthaberg, OR 40610'},
#  {'nombre': 'Jeffrey Garcia',
#   'apellido': 'Potts',
#   'email': 'ucarpenter@example.net',
#   'direccion': '9679 Anderson Causeway Apt. 682\nJameschester, LA 37473'},
#  {'nombre': 'Annette Velazquez',
#   'apellido': 'Vasquez',
#   'email': 'kaylamitchell@example.net',
#   'direccion': '808 John Brook Suite 266\nNew Lauren, MN 94728'},
#  {'nombre': 'Wayne Morris',
#   'apellido': 'Caldwell',
#   'email': 'taylorjoshua@example.com',
#   'direccion': '84116 Blake Ford Apt. 204\nLloydchester, MP 43058'},
#  {'nombre': 'Kaitlyn Perry',
#   'apellido': 'Li',
#   'email': 'watsonjanice@example.net',
#   'direccion': '88251 Chan Fork Suite 994\nJennifermouth, LA 30065'},
#  {'nombre': 'Christina Bonilla',
#   'apellido': 'Reynolds',
#   'email': 'aaustin@example.com',
#   'direccion': '072 Amber Valley\nDanielsberg, DE 24710'},
#  {'nombre': 'Yvette Wood',
#   'apellido': 'Ramirez',
#   'email': 'deborahstone@example.org',
#   'direccion': '11837 Miranda Drive Suite 614\nSouth Stephanie, PW 55290'},
#  {'nombre': 'Steven Serrano',
#   'apellido': 'Bass',
#   'email': 'clloyd@example.org',
#   'direccion': '076 Karen Islands Suite 819\nLake Steven, IA 22303'},
#  {'nombre': 'Jane Beck',
#   'apellido': 'Smith',
#   'email': 'zachary54@example.org',
#   'direccion': '212 Wilson Lake Apt. 556\nSouth John, NV 62513'},
#  {'nombre': 'Jeffrey Murphy',
#   'apellido': 'Davenport',
#   'email': 'mccoykayla@example.com',
#   'direccion': '29652 Heather Meadows Apt. 810\nStephaniehaven, CA 19460'},
#  {'nombre': 'Alexa Schultz',
#   'apellido': 'Velasquez',
#   'email': 'qparker@example.net',
#   'direccion': '71596 Montes Alley\nEast Heiditown, AS 89784'},
#  {'nombre': 'Elizabeth White',
#   'apellido': 'Bridges',
#   'email': 'murphyjessica@example.org',
#   'direccion': '5704 Stephens Crossing Suite 876\nJeffmouth, CA 64730'},
#  {'nombre': 'Penny Beltran',
#   'apellido': 'Mason',
#   'email': 'kim86@example.com',
#   'direccion': '66032 Timothy Extensions Apt. 371\nAlexanderfort, CO 50356'},
#  {'nombre': 'Patrick Diaz',
#   'apellido': 'Harding',
#   'email': 'joshua19@example.com',
#   'direccion': '85936 Tiffany Mall Apt. 445\nSouth Lisa, AS 90666'},
#  {'nombre': 'Jeremy Winters',
#   'apellido': 'Schroeder',
#   'email': 'amy55@example.com',
#   'direccion': '9004 Jorge Loop Apt. 192\nAlexisport, PR 01076'},
#  {'nombre': 'Morgan Delgado',
#   'apellido': 'Montoya',
#   'email': 'phelpswalter@example.org',
#   'direccion': '4529 Linda Ports Apt. 853\nHoweland, LA 43406'},
#  {'nombre': 'Ronald Perry',
#   'apellido': 'Green',
#   'email': 'scottvictor@example.org',
#   'direccion': '37511 Justin Club\nPort Laura, TN 40656'},
#  {'nombre': 'Sonya Scott',
#   'apellido': 'Sanchez',
#   'email': 'gclark@example.org',
#   'direccion': '70349 Andrew Pines\nTracyview, UT 20414'},
#  {'nombre': 'Abigail Stevens',
#   'apellido': 'Webb',
#   'email': 'johnspence@example.net',
#   'direccion': '290 Antonio Junctions\nJustinhaven, NH 48233'},
#  {'nombre': 'Kenneth Guzman',
#   'apellido': 'Wright',
#   'email': 'gwilliams@example.com',
#   'direccion': '98157 Daniels Gateway Suite 974\nSouth Heather, IL 38870'},
#  {'nombre': 'Christopher Brown',
#   'apellido': 'Vang',
#   'email': 'carl66@example.net',
#   'direccion': '97951 Castillo Corner Suite 228\nThomasmouth, MH 09730'},
#  {'nombre': 'Timothy Myers',
#   'apellido': 'Allen',
#   'email': 'matthewgarcia@example.org',
#   'direccion': '8248 Alexander Creek\nMurphyberg, UT 90458'},
#  {'nombre': 'Danielle Hernandez',
#   'apellido': 'Padilla',
#   'email': 'kprice@example.com',
#   'direccion': '35986 Kathryn Road Apt. 015\nOrtizmouth, PA 27979'},
#  {'nombre': 'Julie Smith',
#   'apellido': 'Martinez',
#   'email': 'lesliewilliams@example.org',
#   'direccion': '835 Mathews Locks Suite 988\nNew Adamhaven, UT 69368'},
#  {'nombre': 'Evan Goodman',
#   'apellido': 'Brown',
#   'email': 'dianaoconnor@example.net',
#   'direccion': 'USS Obrien\nFPO AA 80312'},
#  {'nombre': 'Anthony Smith',
#   'apellido': 'Wall',
#   'email': 'robertstrickland@example.org',
#   'direccion': '496 Williamson Springs Apt. 529\nNorth Eric, MP 45873'},
#  {'nombre': 'Tracy Miller',
#   'apellido': 'Brown',
#   'email': 'barreradonna@example.com',
#   'direccion': 'USNS Wallace\nFPO AE 51794'},
#  {'nombre': 'Deborah Johnson',
#   'apellido': 'Oneill',
#   'email': 'andrewfoster@example.org',
#   'direccion': '4484 John Camp Suite 837\nLake Joseph, OK 70558'},
#  {'nombre': 'Gabriel Wilson',
#   'apellido': 'Coleman',
#   'email': 'thomasflowers@example.com',
#   'direccion': '09836 Kelly Trace\nLake Stacyview, CA 78181'},
#  {'nombre': 'Nicole Nichols',
#   'apellido': 'Wong',
#   'email': 'hortonpatrick@example.net',
#   'direccion': '2776 Kyle Hill Suite 033\nLake Connie, SC 51354'},
#  {'nombre': 'Olivia Gould',
#   'apellido': 'Carroll',
#   'email': 'bradleyanderson@example.org',
#   'direccion': '2713 Vickie Ford\nWilsonshire, MP 84098'},
#  {'nombre': 'Amanda Bowers',
#   'apellido': 'French',
#   'email': 'lindafoster@example.com',
#   'direccion': 'PSC 1899, Box 3253\nAPO AA 48747'},
#  {'nombre': 'Cynthia Rice',
#   'apellido': 'Edwards',
#   'email': 'kyletanner@example.com',
#   'direccion': 'Unit 3515 Box 2649\nDPO AA 44054'},
#  {'nombre': 'Michele Nelson',
#   'apellido': 'Alexander',
#   'email': 'kim94@example.com',
#   'direccion': '28098 Robert Crescent Apt. 631\nEast Karatown, PR 14549'},
#  {'nombre': 'Anthony Day',
#   'apellido': 'Olson',
#   'email': 'hoffmanrachel@example.net',
#   'direccion': '089 Anderson Course Suite 547\nJosephchester, PA 80119'},
#  {'nombre': 'Michael Miranda',
#   'apellido': 'Sullivan',
#   'email': 'joseph85@example.com',
#   'direccion': '2303 Burton Spring\nNorth David, NJ 73241'},
#  {'nombre': 'Diane Lee',
#   'apellido': 'George',
#   'email': 'amandaglover@example.net',
#   'direccion': '4350 Hendrix Park Suite 036\nWellsburgh, MH 54829'},
#  {'nombre': 'Sarah Jones',
#   'apellido': 'Wolf',
#   'email': 'rodriguezmichele@example.org',
#   'direccion': '9665 James Fort\nSouth Adam, DC 72713'},
#  {'nombre': 'Laura Burgess',
#   'apellido': 'Walters',
#   'email': 'erin11@example.net',
#   'direccion': '3595 Jade Lodge Suite 230\nPottshaven, AK 06195'},
#  {'nombre': 'Katherine Stanley DVM',
#   'apellido': 'Williams',
#   'email': 'htorres@example.net',
#   'direccion': 'PSC 0852, Box 2600\nAPO AP 85062'},
#  {'nombre': 'Tanya Barrett',
#   'apellido': 'Maddox',
#   'email': 'rodriguezheidi@example.net',
#   'direccion': '5066 Anderson Orchard\nNew Ruben, FL 19534'},
#  {'nombre': 'Ryan Sherman',
#   'apellido': 'Russell',
#   'email': 'hrandolph@example.net',
#   'direccion': '28590 Parker Manors Suite 910\nNorth Amyton, VT 56437'},
#  {'nombre': 'James Fisher',
#   'apellido': 'Ingram',
#   'email': 'brittanyrobinson@example.net',
#   'direccion': '4243 Young Ville\nPort Linda, ND 72054'},
#  {'nombre': 'Amanda Carter',
#   'apellido': 'Barker',
#   'email': 'joshua71@example.com',
#   'direccion': '2969 Joseph Canyon Suite 333\nConleyshire, FM 88815'},
#  {'nombre': 'Tracy Navarro',
#   'apellido': 'Baker',
#   'email': 'tammygray@example.net',
#   'direccion': '812 Christopher Grove Apt. 348\nDavidland, FL 38146'},
#  {'nombre': 'Wendy Gilmore',
#   'apellido': 'Allen',
#   'email': 'sallen@example.net',
#   'direccion': '8879 Nicholas Trace Apt. 559\nLake Joseph, MD 99088'},
#  {'nombre': 'Lori Braun',
#   'apellido': 'Diaz',
#   'email': 'ilewis@example.net',
#   'direccion': '855 Courtney Expressway\nNorth Shannonton, MO 79441'},
#  {'nombre': 'Aaron Castillo',
#   'apellido': 'Love',
#   'email': 'qdavis@example.org',
#   'direccion': 'Unit 1689 Box 5906\nDPO AP 57684'},
#  {'nombre': 'Rebecca Newman',
#   'apellido': 'Scott',
#   'email': 'richtyler@example.com',
#   'direccion': 'PSC 2471, Box 6699\nAPO AA 86741'},
#  {'nombre': 'Kenneth Garcia',
#   'apellido': 'Acosta',
#   'email': 'bhood@example.com',
#   'direccion': '504 Melissa Divide\nBradshawland, NH 92530'},
#  {'nombre': 'Michele Delacruz',
#   'apellido': 'Robertson',
#   'email': 'hsmith@example.net',
#   'direccion': 'USNV Rose\nFPO AE 77935'},
#  {'nombre': 'Andrew Costa',
#   'apellido': 'Morgan',
#   'email': 'mclaughlinsteven@example.com',
#   'direccion': '6117 Aaron Prairie\nNorth Gregory, OR 38432'},
#  {'nombre': 'David Rocha',
#   'apellido': 'Johnson',
#   'email': 'dixonemily@example.com',
#   'direccion': '720 Peck Knolls Suite 608\nKruegerview, MD 99174'},
#  {'nombre': 'Michele Jones',
#   'apellido': 'Weaver',
#   'email': 'moniquehester@example.net',
#   'direccion': 'USNS Thomas\nFPO AA 14723'},
#  ...]

# %%
df = pd.DataFrame(lista)

# %%
import random

# %%
# Provincias permitidas
provincias = ['Loja', 'Pichincha', 'Guayas', 'Azuay', 'Manabí']

# Agregar edad y provincia
df['edad'] = [fake.random_int(min=30, max=40) for j in range(len(df))]
df['provincia'] = [random.choice(provincias) for x in range(len(df))]

# %%
df
# Out:
#                 nombre   apellido                       email  \
# 0          Laura Bryan     Hunter        xbarnett@example.net
# 1      Katherine Smith   Anderson  terrihernandez@example.net
# 2      Bernard Gardner     Thomas        mayojill@example.org
# 3         Sandy Harris   Mckinney         kevin87@example.org
# 4         Shannon Pope     Martin      wendywells@example.net
# ...                ...        ...                         ...
# 9995     Valerie Lewis     Howard     normagarcia@example.net
# 9996  Christina Thomas   Martinez   lindseytorres@example.org
# 9997        Adam White       Neal       deborah09@example.net
# 9998    Michael Snyder      Patel     aarontorres@example.org
# 9999       James Nunez  Whitehead    stevenhardin@example.org
#
#                                               direccion  edad  provincia
# 0         1338 Amy Valley Apt. 265\nTammyfurt, SD 98889    38     Manabí
# 1                      Unit 3379 Box 0005\nDPO AP 28086    35  Pichincha
# 2     539 Lawrence Stream\nEast Christophertown, CA ...    32  Pichincha
# 3                              USNS Brown\nFPO AA 25533    30      Azuay
# 4                  5881 Johnson Track\nGayton, WV 96401    32     Guayas
# ...                                                 ...   ...        ...
# 9995  269 Martin Mountains Apt. 365\nEast Cherylfurt...    32       Loja
# 9996    80448 Hunter Stream\nEast Jeffreyport, CA 72297    37  Pichincha
# 9997     931 Sabrina Flat Apt. 199\nLucasbury, KY 23888    39      Azuay
# 9998         7014 Blake Village\nWilliamsport, TN 32760    33       Loja
# 9999  689 Norton Ferry Suite 372\nPort Vincent, PR 0...    39  Pichincha
#
# [10000 rows x 6 columns]

# %%
df.to_csv('conjunto_datos.csv')
